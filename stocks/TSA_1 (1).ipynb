# %% [markdown]
# <a href="https://colab.research.google.com/github/ambitious08/TSA-LAB/blob/main/TSA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("autism_screening.csv")


print(data.isnull().sum())
data.columns = data.columns.str.strip()
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                2
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %%
print(f"Number of duplicates: {data.duplicated().sum()}")
data.drop_duplicates(inplace=True)
# Out:
# Number of duplicates: 5

# %%
print(data.head())
print(data.tail())
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice austim  \
# 0         1         0          0  ...       f  White-European      no     no
# 1         1         0          1  ...       m          Latino      no    yes
# 2         1         1          1  ...       m          Latino     yes    yes
# 3         1         0          1  ...       f  White-European      no    yes
# 4         1         0          0  ...       f               ?      no     no
#
# ...

# %%
print(data.describe())
# Out:
#          A1_Score    A2_Score    A3_Score    A4_Score    A5_Score    A6_Score  \
# count  699.000000  699.000000  699.000000  699.000000  699.000000  699.000000
# mean     0.719599    0.450644    0.454936    0.496423    0.496423    0.283262
# std      0.449517    0.497914    0.498322    0.500345    0.500345    0.450905
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          A7_Score    A8_Score    A9_Score   A10_Score         age      result
# count  699.000000  699.000000  699.000000  699.000000  697.000000  699.000000
# mean     0.416309    0.646638    0.323319    0.575107   29.692970    4.862661
# ...

# %%
plt.figure(figsize=(10, 6))
data.hist(bins=20, figsize=(15, 10))
plt.show()
